# %%
import saspy
saspy
# Out:
# <module 'saspy' from '/opt/tom/github/saspy/saspy/__init__.py'>

# %%
sas = saspy.SASsession(results='pandas', cfgname='sdssas')
sas
# Out:
# SAS Connection established. Subprocess id is 12868
#
# No encoding value provided. Will try to determine the correct encoding.
# Setting encoding to iso8859_15 based upon the SAS session encoding value of latin9.
# Access Method         = STDIO
# SAS Config name       = sdssas
# WORK Path             = /sastmp/SAS_workC96B00003260_tom64-5/
# SAS Version           = 9.04.01M4D11092016
# SASPy Version         = 2.4.4
# Teach me SAS          = False
# Batch                 = False
# Results               = pandas
# SAS Session Encoding  = latin9
# Python Encoding value = iso8859_15
# SAS process Pid value = 12896

# %%
stat = sas.sasstat()

# %%
cars = sas.sasdata('cars', libref='sashelp')

# %%
cars.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-eebb05d22726> in <module>()
# ----> 1 cars.head()
#
# /opt/tom/github/saspy/saspy/sasdata.py in head(self, obs)
#     205         if self.results.upper() == 'PANDAS':
#     206             code = "data _head ; set %s.%s %s; run;" % (self.libref, self.table, self.sas._dsopts(topts))
# --> 207             return self._returnPD(code, '_head')
#     208         else:
#     209             ll = self._is_valid()
#
# /opt/tom/github/saspy/saspy/sasdata.py in _returnPD(self, code, tablename, **kwargs)
#     148         """
#     149         if self.sas.sascfg.pandas:
# --> 150            raise type(self.sas.sascfg.pandas)(self.sas.sascfg.pandas.msg)
#     151
#     152         libref = kwargs.get('libref','work')
#
# ImportError: No module named 'pandas'

# %%
stat_results = stat.reg(model='horsepower = Cylinders EngineSize', data=cars) #by='origin' ,data=cars)
dir(stat_results)
# Out:
# ['ANOVA',
#  'COOKSDPLOT',
#  'DFBETASPANEL',
#  'DFFITSPLOT',
#  'DIAGNOSTICSPANEL',
#  'FITSTATISTICS',
#  'LOG',
#  'NOBS',
#  'OBSERVEDBYPREDICTED',
#  'PARAMETERESTIMATES',
#  'QQPLOT',
#  'RESIDUALBOXPLOT',
#  'RESIDUALBYPREDICTED',
#  'RESIDUALHISTOGRAM',
#  'RESIDUALPLOT',
#  'RFPLOT',
#  'RSTUDENTBYLEVERAGE',
#  'RSTUDENTBYPREDICTED']

# %%
stat_results.FITSTATISTICS
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-2a5ba03cf273> in <module>()
# ----> 1 stat_results.FITSTATISTICS
#
# /opt/tom/github/saspy/saspy/sasresults.py in __getattr__(self, attr, all)
#      60
#      61         if attr.upper() in self._names:
# ---> 62             data = self._go_run_code(attr)
#      63         else:
#      64             if self.nosub:
#
# /opt/tom/github/saspy/saspy/sasresults.py in _go_run_code(self, attr)
#      95
#      96             if self.sas.results.upper() == 'PANDAS':
# ---> 97                df = self.sas.sasdata2dataframe(attr, libref=lref)
#      98             else:
#      99                code = '%%getdata(%s, %s);' % (self._name, attr)
#
# /opt/tom/github/saspy/saspy/sasbase.py in sasdata2dataframe(self, table, libref, dsopts, method, **kwargs)
#     973         """
#     974         if self.sascfg.pandas:
# ...

# %%
stat_results.DIAGNOSTICSPANEL
# Out:
# <h1>DIAGNOSTICSPANEL</h1><!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
stat_results.ALL()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-5fdaa843b43e> in <module>()
# ----> 1 stat_results.ALL()
#
# /opt/tom/github/saspy/saspy/sasresults.py in ALL(self)
#     113            for i in self._names:
#     114                if i.upper() != 'LOG' and i.upper() != 'ERROR_LOG':
# --> 115                    x = self.__getattr__(i)
#     116                    if x is not None:
#     117                       if self.sas.sascfg.display.lower() == 'zeppelin':
#
# /opt/tom/github/saspy/saspy/sasresults.py in __getattr__(self, attr, all)
#      60
#      61         if attr.upper() in self._names:
# ---> 62             data = self._go_run_code(attr)
#      63         else:
#      64             if self.nosub:
#
# /opt/tom/github/saspy/saspy/sasresults.py in _go_run_code(self, attr)
#      95
#      96             if self.sas.results.upper() == 'PANDAS':
# ...

# %%
stat_results.COOKSDPLOT
# Out:
# <h1>COOKSDPLOT</h1><!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
df = cars.to_df()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-58cda2f79ff4> in <module>()
# ----> 1 df = cars.to_df()
#
# /opt/tom/github/saspy/saspy/sasdata.py in to_df(self, method, **kwargs)
#     988         else:
#     989             if self.sas.sascfg.pandas:
# --> 990                raise type(self.sas.sascfg.pandas)(self.sas.sascfg.pandas.msg)
#     991             return self.sas.sasdata2dataframe(self.table, self.libref, self.dsopts, method, **kwargs)
#     992
#
# ImportError: No module named 'pandas'

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-38d4b0363d82> in <module>()
# ----> 1 import pandas
#
# ImportError: No module named 'pandas'

# %%
cls = sas.sasdata('class','sashelp', results='html')

# %%
cls.head()
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...
