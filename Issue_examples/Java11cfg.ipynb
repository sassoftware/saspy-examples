# %%
import saspy
sas_wo = saspy.SASsession(cfgfile='Java11cfg.py', cfgname='without')
sas_wo
# Out:
# Java Error:
# Error: Unable to initialize main class pyiom.saspy2j
# Caused by: java.lang.NoClassDefFoundError: org/omg/CORBA/COMM_FAILURE
#
#
# Subprocess failed to start. Double check your settings in sascfg_personal.py file.
#
# ...

# %%
import saspy
sas_wi = saspy.SASsession(cfgfile='Java11cfg.py', cfgname='withit')
sas_wi
# Out:
# SAS Connection established. Subprocess id is 26956
# Access Method         = IOM
# SAS Config name       = withit
# WORK Path             = C:\Users\sastpw\AppData\Local\Temp\SAS Temporary Files\_TD2844_d10a626_\Prc2\
# SAS Version           = 9.04.01M5P09132017
# SASPy Version         = 3.1.0
# Teach me SAS          = False
# Batch                 = False
# Results               = Pandas
# SAS Session Encoding  = wlatin1
# Python Encoding value = windows-1252
# SAS process Pid value = 2844

# %%
cars_wi = sas_wi.sasdata('cars','sashelp')

# %%
cars_wi.hist('horsepower')
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
import saspy
sas_w8 = saspy.SASsession(cfgfile='Java11cfg.py', cfgname='withitJava8')
sas_w8
# Out:
# SAS Connection established. Subprocess id is 4948
# Access Method         = IOM
# SAS Config name       = withitJava8
# WORK Path             = C:\Users\sastpw\AppData\Local\Temp\SAS Temporary Files\_TD23052_d10a626_\Prc2\
# SAS Version           = 9.04.01M5P09132017
# SASPy Version         = 3.1.0
# Teach me SAS          = False
# Batch                 = False
# Results               = Pandas
# SAS Session Encoding  = wlatin1
# Python Encoding value = windows-1252
# SAS process Pid value = 23052

# %%
cars_w8 = sas_w8.sasdata('cars','sashelp')

# %%
cars_w8.hist('mpg_city')
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
import saspy
sas_w8r = saspy.SASsession(cfgfile='Java11cfg.py', cfgname='withitJava8r')
sas_w8r
# Out:
# SAS Connection established. Subprocess id is 26436
# Access Method         = IOM
# SAS Config name       = withitJava8r
# WORK Path             = C:\Users\sastpw\AppData\Local\Temp\SAS Temporary Files\_TD10404_d10a626_\Prc2\
# SAS Version           = 9.04.01M5P09132017
# SASPy Version         = 3.1.0
# Teach me SAS          = False
# Batch                 = False
# Results               = Pandas
# SAS Session Encoding  = wlatin1
# Python Encoding value = windows-1252
# SAS process Pid value = 10404

# %%
cars_w8r = sas_w8r.sasdata('cars','sashelp')

# %%
cars_w8r.hist('msrp')
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
fd = open('Java11cfg.py', 'r')
dat = fd.read()
fd.close()
print(dat)
# Out:
# SAS_config_names=["withit", "without", "withitJava8", "withitJava8r"]
#
# SAS_config_options = {
# 	"lock_down": False,
# 	"verbose"  : True
# 	}
#
# cpW  =  "C:\\Program Files\\SASHome\\SASDeploymentManager\\9.4\\products\\deploywiz__94508__prt__xx__sp0__1\\deploywiz\\sas.core.jar"
# cpW += ";C:\\Program Files\\SASHome\\SASDeploymentManager\\9.4\\products\\deploywiz__94508__prt__xx__sp0__1\\deploywiz\\sas.svc.connection.jar"
# cpW += ";C:\\Program Files\\SASHome\\SASDeploymentManager\\9.4\\products\\deploywiz__94508__prt__xx__sp0__1\\deploywiz\\log4j.jar"
# cpW += ";C:\\Program Files\\SASHome\\SASDeploymentManager\\9.4\\products\\deploywiz__94508__prt__xx__sp0__1\\deploywiz\\sas.security.sspi.jar"
# cpW += ";C:\\ProgramData\\Anaconda3\\lib\\site-packages\\saspy\\java\\saspyiom.jar"
#
# #cp11 = "C:\\IOMCorba\\dist\\sas.iom.corba.jar;C:\\IOMCorba\\dist\\sas.iom.corba.nls.jar"
# ...
